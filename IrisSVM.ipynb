# %% [markdown]
# # IrisSVM
# *******************************************************************************************************************************

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the data

# %%
iris = sns.load_dataset('iris')
#Dataset from Seaborn stock

# %% [markdown]
# ## Plot for visualization

# %%
sns.pairplot(iris,hue='species',palette='Dark2')
# Setosa is the most differentiated.

# %% [markdown]
# ## Split data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
X = iris.drop('species',axis=1)
y = iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Create and train model for Support Vector Machine classifier

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ## Predictions for SVC

# %%
predictions = svc_model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
#confusion matrix and classification report for checking
print(confusion_matrix(y_test,predictions))
# Out:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  1 10]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       0.94      0.94      0.94        18
#    virginica       0.91      0.91      0.91        11
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
#############            the result is good enough, despite the fact, it will be optimized         #############

# %% [markdown]
# ## Gridsearch optimization

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]} 
# C and Gamma adjust range for loop test and optimization

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# ...

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[16  0  0]
#  [ 0 18  0]
#  [ 0  1 10]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       0.95      1.00      0.97        18
#    virginica       1.00      0.91      0.95        11
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
